# %% [markdown]
# <a href="https://colab.research.google.com/github/harishsdev/NLP/blob/main/nlp_finetuning_algos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/twitter-disaster-prediction-dataset-master.zip (Unzipped Files)
# Out:
# /content/drive/MyDrive/twitter-disaster-prediction-dataset-master.zip (Unzipped Files)

# %% [markdown]
# 1.Load the library
#
# 2.Load the dataset
#
#      *select the feature coloumn
#
#      *select the target coloumn
#
# 3.Declare the mlalgo to use
#
# 3.Train it
#
# 4.Predict it
#
# Finetuing of ML Algorithms:-
#
# 1.PCA
#
# 2.LDA
#
# 3.NMF
#
# 4.TSVD

# %%
# !ls
# Out:
# twitter-disaster-prediction-dataset-master

# %%
# %cd twitter-disaster-prediction-dataset-master/
# Out:
# /content/drive/My Drive/twitter-disaster-prediction-dataset-master.zip (Unzipped Files)/twitter-disaster-prediction-dataset-master

# %%
# !ls
# Out:
# README.md  train.csv

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df=pd.read_csv(r'train.csv')

# %%
df
# Out:
#          id keyword  ...                                               text target
# 0         1     NaN  ...  Our Deeds are the Reason of this #earthquake M...      1
# 1         4     NaN  ...             Forest fire near La Ronge Sask. Canada      1
# 2         5     NaN  ...  All residents asked to 'shelter in place' are ...      1
# 3         6     NaN  ...  13,000 people receive #wildfires evacuation or...      1
# 4         7     NaN  ...  Just got sent this photo from Ruby #Alaska as ...      1
# ...     ...     ...  ...                                                ...    ...
# 7608  10869     NaN  ...  Two giant cranes holding a bridge collapse int...      1
# 7609  10870     NaN  ...  @aria_ahrary @TheTawniest The out of control w...      1
# 7610  10871     NaN  ...  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...      1
# 7611  10872     NaN  ...  Police investigating after an e-bike collided ...      1
# 7612  10873     NaN  ...  The Latest: More Homes Razed by Northern Calif...      1
#
# [7613 rows x 5 columns]

# %%
df['target'].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
x=df['text']
y=df['target']

# %%
x
# Out:
# 0       Our Deeds are the Reason of this #earthquake M...
# 1                  Forest fire near La Ronge Sask. Canada
# 2       All residents asked to 'shelter in place' are ...
# 3       13,000 people receive #wildfires evacuation or...
# 4       Just got sent this photo from Ruby #Alaska as ...
#                               ...
# 7608    Two giant cranes holding a bridge collapse int...
# 7609    @aria_ahrary @TheTawniest The out of control w...
# 7610    M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611    Police investigating after an e-bike collided ...
# 7612    The Latest: More Homes Razed by Northern Calif...
# Name: text, Length: 7613, dtype: object

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7608    1
# 7609    1
# 7610    1
# 7611    1
# 7612    1
# Name: target, Length: 7613, dtype: int64

# %%
tfidf=TfidfVectorizer()
x=tfidf.fit_transform(x)

# %%
x
# Out:
# <7613x21637 sparse matrix of type '<class 'numpy.float64'>'
# 	with 111497 stored elements in Compressed Sparse Row format>

# %%
#it has a sparse
#do dimensionality reduction

# %%
tfidf.vocabulary_
# Out:
# {'our': 14003,
#  'deeds': 5490,
#  'are': 2192,
#  'the': 18669,
#  'reason': 15678,
#  'of': 13681,
#  'this': 18777,
#  'earthquake': 6379,
#  'may': 12141,
#  'allah': 1852,
#  'forgive': 7661,
#  'us': 19774,
#  'all': 1851,
#  'forest': 7652,
#  'fire': 7439,
#  'near': 13122,
#  'la': 11091,
#  'ronge': 16266,
#  'sask': 16611,
#  'canada': 3843,
#  'residents': 15940,
#  'asked': 2312,
#  'to': 18971,
#  'shelter': 17022,
#  'in': 9718,
#  'place': 14612,
#  'being': 2900,
#  'notified': 13423,
#  'by': 3698,
#  'officers': 13701,
#  'no': 13335,
#  'other': 13987,
#  'evacuation': 6909,
#  'or': 13919,
#  'orders': 13936,
#  'expected': 7014,
#  '13': 176,
#  '000': 1,
#  'people': 14389,
#  'receive': 15699,
#  'wildfires': 20607,
#  'california': 3797,
#  'just': 10550,
#  'got': 8364,
#  'sent': 16870,
#  'photo': 14500,
#  'from': 7823,
#  'ruby': 16379,
#  'alaska': 1800,
#  'as': 2280,
#  'smoke': 17394,
#  'pours': 14821,
#  'into': 9947,
#  'school': 16700,
#  'rockyfire': 16219,
#  'update': 19722,
#  'hwy': 9399,
#  '20': 343,
#  'closed': 4462,
#  'both': 3346,
#  'directions': 5819,
#  'due': 6248,
#  'lake': 11118,
#  'county': 4915,
#  'cafire': 3768,
#  'flood': 7546,
#  'disaster': 5841,
#  'heavy': 8915,
#  'rain': 15524,
#  'causes': 4017,
#  'flash': 7508,
#  'flooding': 7548,
#  'streets': 17975,
#  'manitou': 11984,
#  'colorado': 4604,
#  'springs': 17706,
#  'areas': 2195,
#  'on': 13824,
#  'top': 19040,
#  'hill': 9049,
#  'and': 1984,
#  'can': 3841,
#  'see': 16808,
#  'woods': 20763,
#  'there': 18732,
#  'an': 1968,
#  'emergency': 6609,
#  'happening': 8754,
#  'now': 13439,
#  'building': 3606,
#  'across': 1539,
#  'street': 17972,
#  'afraid': 1658,
#  'that': 18659,
#  'tornado': 19053,
#  'is': 10043,
#  'coming': 4633,
#  'area': 2193,
#  'three': 18818,
#  'died': 5774,
#  'heat': 8910,
#  'wave': 20384,
#  'so': 17448,
#  'far': 7208,
#  'haha': 8684,
#  'south': 17572,
#  'tampa': 18396,
#  'getting': 8140,
#  'flooded': 7547,
#  'hah': 8683,
#  'wait': 20280,
#  'second': 16792,
#  'live': 11523,
#  'what': 20533,
#  'am': 1914,
#  'gonna': 8332,
#  'do': 5988,
#  'fvck': 7907,
#  'raining': 15531,
#  'florida': 7558,
#  'tampabay': 18397,
#  '18': 232,
#  '19': 245,
#  'days': 5392,
#  've': 19964,
#  'lost': 11683,
#  'count': 4908,
#  'bago': 2631,
#  'myanmar': 12931,
#  'we': 20422,
#  'arrived': 2248,
#  'damage': 5285,
#  'bus': 3656,
#  '80': 1117,
#  'multi': 12852,
#  'car': 3904,
#  'crash': 4977,
#  'breaking': 3444,
#  'up': 19718,
#  'man': 11965,
#  'love': 11697,
#  'fruits': 7836,
#  'summer': 18110,
#  'lovely': 11701,
#  'my': 12929,
#  'fast': 7227,
#  'goooooooaaaaaal': 8350,
#  'ridiculous': 16089,
#  'london': 11627,
#  'cool': 4832,
#  'skiing': 17266,
#  'wonderful': 20750,
#  'day': 5391,
#  'looooool': 11651,
#  'way': 20388,
#  'eat': 6395,
#  'shit': 17052,
#  'was': 20345,
#  'nyc': 13545,
#  'last': 11176,
#  'week': 20461,
#  'girlfriend': 8217,
#  'cooool': 4837,
#  'you': 21285,
#  'like': 11450,
#  'pasta': 14268,
#  'end': 6676,
#  'bbcmtd': 2783,
#  'wholesale': 20577,
#  'markets': 12046,
#  'ablaze': 1452,
#  'http': 9304,
#  'co': 4517,
#  'lhyxeohy6c': 11394,
#  'always': 1911,
#  'try': 19308,
#  'bring': 3492,
#  'metal': 12313,
#  'rt': 16360,
#  'yao1e0xngw': 21162,
#  'africanbaze': 1662,
#  'news': 13195,
#  'nigeria': 13254,
#  'flag': 7499,
#  'set': 16909,
#  'aba': 1424,
#  '2nndbgwyei': 482,
#  'crying': 5086,
#  'out': 14006,
#  'for': 7633,
#  'more': 12698,
#  'me': 12191,
#  'plus': 14683,
#  'side': 17124,
#  'look': 11644,
#  'at': 2358,
#  'sky': 17284,
#  'night': 13260,
#  'it': 10072,
#  'qqsmshaj3n': 15343,
#  'phdsquares': 14476,
#  'mufc': 12840,
#  'they': 18755,
#  'built': 3610,
#  'much': 12834,
#  'hype': 9414,
#  'around': 2238,
#  'new': 13181,
#  'acquisitions': 1536,
#  'but': 3672,
#  'doubt': 6080,
#  'will': 20611,
#  'epl': 6779,
#  'season': 16778,
#  'inec': 9794,
#  'office': 13698,
#  'abia': 1449,
#  '3imaomknna': 614,
#  'barbados': 2695,
#  'bridgetown': 3478,
#  'jamaica': 10194,
#  'ûò': 21627,
#  'two': 19415,
#  'cars': 3957,
#  'santa': 16595,
#  'cruz': 5083,
#  'ûó': 21631,
#  'head': 8870,
#  'st': 17765,
#  'elizabeth': 6572,
#  'police': 14733,
#  'superintende': 18149,
#  'wdueaj8q4j': 20417,
#  'lord': 11663,
#  'check': 4197,
#  'these': 18741,
#  'roi2nsmejj': 16235,
#  '3tj8zjin21': 646,
#  'yduixefipe': 21184,
#  'lxtjc87kls': 11799,
#  'nsfw': 13474,
#  'outside': 14027,
#  're': 15633,
#  'alive': 1849,
#  'dead': 5421,
#  'inside': 9863,
#  'had': 8679,
#  'awesome': 2512,
#  'time': 18886,
#  'visiting': 20110,
#  'cfc': 4100,
#  'ancop': 1983,
#  'site': 17223,
#  'thanks': 18656,
#  'tita': 18916,
#  'vida': 20051,
#  'taking': 18376,
#  'care': 3916,
#  'soooo': 17536,
#  'pumped': 15156,
#  'southridgelife': 17581,
#  'wanted': 20311,
#  'chicago': 4232,
#  'with': 20675,
#  'preaching': 14876,
#  'not': 13409,
#  'hotel': 9243,
#  'o9qknbfofx': 13597,
#  'gained': 7986,
#  'followers': 7608,
#  'know': 10935,
#  'your': 21294,
#  'stats': 17839,
#  'grow': 8502,
#  'tiyulif5c6': 18927,
#  'how': 9258,
#  'west': 20496,
#  'burned': 3644,
#  'thousands': 18803,
#  'alone': 1886,
#  'vl5tbr3wbr': 20136,
#  'perfect': 14396,
#  'tracklist': 19127,
#  'life': 11421,
#  'leave': 11277,
#  'first': 7462,
#  'retainers': 15987,
#  'quite': 15398,
#  'weird': 20473,
#  'better': 2978,
#  'get': 8136,
#  'used': 19795,
#  'have': 8826,
#  'wear': 20435,
#  'them': 18713,
#  'every': 6930,
#  'single': 17190,
#  'next': 13213,
#  'year': 21190,
#  'least': 11275,
#  'deputies': 5617,
#  'shot': 17082,
#  'before': 2876,
#  'brighton': 3488,
#  'home': 9156,
#  'gwnrhmso8k': 8612,
#  'wife': 20599,
#  'six': 17232,
#  'years': 21191,
#  'jail': 10182,
#  'setting': 16915,
#  'niece': 13250,
#  'ev1ahoucza': 6901,
#  'superintendent': 18150,
#  'lanford': 11152,
#  'salmon': 16541,
#  'has': 8801,
#  'vplr5hka2u': 20191,
#  'sxhw2tnnlf': 18284,
#  'arsonist': 2256,
#  'deliberately': 5542,
#  'black': 3134,
#  'church': 4324,
#  'north': 13386,
#  'carolinaåêablaze': 3947,
#  'pcxarbh9an': 14338,
#  'noches': 13345,
#  'el': 6527,
#  'bestia': 2966,
#  'alexis_sanchez': 1830,
#  'happy': 8760,
#  'teammates': 18504,
#  'training': 19152,
#  'hard': 8768,
#  'goodnight': 8341,
#  'gunners': 8581,
#  'uc4j4jhvgr': 19503,
#  'kurds': 11023,
#  'trampling': 19158,
#  'turkmen': 19363,
#  'later': 11185,
#  'while': 20554,
#  'others': 13988,
#  'vandalized': 19923,
#  'offices': 13702,
#  'front': 7824,
#  'diyala': 5931,
#  '4izfdyc3cg': 744,
#  'truck': 19286,
#  'r21': 15456,
#  'voortrekker': 20178,
#  'ave': 2478,
#  'tambo': 18393,
#  'intl': 9946,
#  'cargo': 3928,
#  'section': 16798,
#  '8kscqkfkkf': 1182,
#  'hearts': 8908,
#  'city': 4362,
#  'gift': 8196,
#  'skyline': 17289,
#  'kiss': 10869,
#  'upon': 19736,
#  'lips': 11492,
#  'û_': 21581,
#  'https': 9305,
#  'cyompz1a0z': 5220,
#  'tonight': 19018,
#  'los': 11672,
#  'angeles': 2002,
#  'expecting': 7015,
#  'ig': 9560,
#  'fb': 7259,
#  'be': 2818,
#  'filled': 7400,
#  'sunset': 18139,
#  'shots': 17084,
#  'if': 9551,
#  'peeps': 14370,
#  'icsjgz9te1': 9507,
#  'climate': 4442,
#  'energy': 6693,
#  '9fxmn0l0bd': 1281,
#  'revel': 16013,
#  'yours': 21297,
#  'wmv': 20718,
#  'videos': 20055,
#  'means': 12198,
#  'mac': 11875,
#  'farewell': 7210,
#  'en': 6659,
#  'route': 16310,
#  'dvd': 6293,
#  'gtxrwm': 8537,
#  'progressive': 15013,
#  'greetings': 8459,
#  'about': 1464,
#  'month': 12676,
#  'students': 18025,
#  'would': 20807,
#  'their': 18706,
#  'pens': 14387,
#  'torch': 19048,
#  'publications': 15130,
#  '9fxpixqujt': 1282,
#  'rene': 15867,
#  'amp': 1957,
#  'jacinta': 10158,
#  'secret': 16795,
#  '2k13': 468,
#  'fallen': 7174,
#  'skies': 17265,
#  'edit': 6438,
#  'mar': 12009,
#  '30': 521,
#  '2013': 359,
#  '7mlmsuzv1z': 1088,
#  'navista7': 13076,
#  'steve': 17881,
#  'fires': 7453,
#  'here': 8969,
#  'something': 17508,
#  'else': 6583,
#  'tinderbox': 18901,
#  'clown': 4479,
#  'hood': 9194,
#  'news24680': 13196,
#  'nowplaying': 13442,
#  'ian': 9467,
#  'buff': 3594,
#  'magnitude': 11919,
#  'av2jsjfftc': 2472,
#  'edm': 6444,
#  'nxwestmidlands': 13538,
#  'huge': 9321,
#  'rwzbfvnxer': 16439,
#  'does': 6006,
#  'talk': 18384,
#  'go': 8298,
#  'until': 19703,
#  'don': 6033,
#  'make': 11943,
#  'work': 20771,
#  'kids': 10816,
#  'cuz': 5181,
#  'bicycle': 3022,
#  'accident': 1497,
#  'split': 17673,
#  'testicles': 18607,
#  'impossible': 9698,
#  'michael': 12372,
#  'father': 7240,
#  '24': 403,
#  'nashvilletraffic': 13043,
#  'traffic': 19139,
#  'moving': 12770,
#  '8m': 1187,
#  'slower': 17352,
#  'than': 18650,
#  'usual': 19810,
#  '0ghk693egj': 49,
#  'center': 4079,
#  'lane': 11150,
#  'blocked': 3203,
#  'santaclara': 16596,
#  '101': 123,
#  'nb': 13082,
#  'great': 8438,
#  'america': 1938,
#  'pkwy': 14609,
#  'bayarea': 2770,
#  'pmlohzurwr': 14696,
#  'gkye6gjtk5': 8240,
#  'personalinjury': 14423,
#  'read': 15647,
#  'advice': 1623,
#  'solicitor': 17491,
#  'help': 8952,
#  'otleyhour': 13990,
#  'stlouis': 17905,
#  'caraccidentlawyer': 3907,
#  'speeding': 17636,
#  'among': 1955,
#  'teen': 18532,
#  'accidents': 1501,
#  'k4zomof319': 10605,
#  's2kxvm0cba': 16464,
#  'tee': 18529,
#  'reported': 15896,
#  'motor': 12740,
#  'vehicle': 19975,
#  'curry': 5159,
#  'herman': 8971,
#  'rd': 15626,
#  'stephenson': 17872,
#  'involving': 9981,
#  'overturned': 14059,
#  'please': 14659,
#  'use': 19794,
#  'ybjezkurw1': 21173,
#  'bigrigradio': 3041,
#  'awareness': 2509,
#  '77': 1045,
#  'mile': 12418,
#  'marker': 12039,
#  '31': 538,
#  'mooresville': 12688,
#  'iredell': 10021,
#  'ramp': 15545,
#  'pm': 14687,
#  'sleepjunkies': 17323,
#  'sleeping': 17322,
#  'pills': 14553,
#  'double': 6077,
#  'risk': 16131,
#  '7s9nm1fict': 1104,
#  'knew': 10921,
#  'gon': 8329,
#  'happen': 8752,
#  'ysxun5vceh': 21331,
#  'cabrillo': 3755,
#  'magellan': 11907,
#  'av': 2471,
#  'mir': 12484,
#  '08': 27,
#  '06': 21,
#  '15': 195,
#  '11': 143,
#  '03': 12,
#  '58': 831,
#  '40': 665,
#  'congestion': 4743,
#  'pastor': 14270,
#  'scene': 16689,
#  'who': 20571,
#  'owner': 14074,
#  'range': 15559,
#  'rover': 16316,
#  'mom': 12643,
#  'didn': 5769,
#  'wished': 20669,
#  'why': 20586,
#  'some': 17501,
#  'spilt': 17657,
#  'mayonnaise': 12147,
#  'over': 14035,
#  'horrible': 9222,
#  'past': 14267,
#  'sunday': 18128,
#  'finally': 7413,
#  'able': 1453,
#  'thank': 18651,
#  'god': 8307,
#  'pissed': 14580,
#  'donnie': 6044,
#  'when': 20547,
#  'tell': 18547,
#  'him': 9057,
#  'another': 2050,
#  'truckcrash': 19287,
#  'overturns': 14060,
#  'fortworth': 7686,
#  'interstate': 9938,
#  'rs22lj4qfp': 16347,
#  'click': 4435,
#  'been': 2868,
#  'gt': 8527,
#  'ld0uniyw4k': 11242,
#  'ashville': 2303,
#  '23': 394,
#  'sb': 16657,
#  'sr': 17743,
#  '752': 1041,
#  'hylmo0wgfi': 9413,
#  'carolina': 3945,
#  'motorcyclist': 12744,
#  'dies': 5777,
#  '540': 818,
#  'crossed': 5053,
#  'median': 12216,
#  'motorcycle': 12742,
#  'rider': 16086,
#  'traveling': 19186,
#  'p18lzrlmy6': 14093,
#  'fyi': 7936,
#  'cad': 3760,
#  'property': 15046,
#  'nhs': 13232,
#  '999': 1264,
#  'piner': 14558,
#  'horndale': 9215,
#  'dr': 6110,
#  'naayf': 12997,
#  'turning': 19368,
#  'onto': 13851,
#  'chandanee': 4140,
#  'magu': 11924,
#  'mma': 12577,
#  'taxi': 18445,
#  'rammed': 15544,
#  'halfway': 8707,
#  'turned': 19365,
#  'everyone': 6934,
#  'conf': 4730,
#  'left': 11292,
#  'manchester': 11971,
#  '293': 432,
#  'eddy': 6430,
#  'stop': 17924,
#  'back': 2594,
#  'nh': 13227,
#  '3a': 587,
#  'delay': 5535,
#  'mins': 12474,
#  'oia5fxi4gm': 13749,
#  'wpd': 20820,
#  '1600': 211,
#  '17th': 230,
#  '2015': 361,
#  '09': 33,
#  'injury': 9842,
#  '2781': 422,
#  'willis': 20620,
#  'foreman': 7650,
#  'vckit6edev': 19956,
#  'aashiqui': 1419,
#  'actress': 1559,
#  'anu': 2074,
#  'aggarwal': 1697,
#  'her': 8968,
#  'fatal': 7233,
#  '6otfp31lqw': 984,
#  'suffield': 18093,
#  'alberta': 1806,
#  'bptmlf4p10': 3394,
#  'backup': 2604,
#  'blocking': 3204,
#  'right': 16097,
#  'lanes': 11151,
#  'exit': 6998,
#  'langtree': 11155,
#  'consider': 4766,
#  'nc': 13099,
#  '115': 150,
#  '150': 196,
#  '16': 209,
#  'alternate': 1902,
#  'changed': 4143,
#  'determine': 5680,
#  'options': 13909,
#  'financially': 7416,
#  'support': 18162,
#  'plans': 14630,
#  'going': 8321,
#  'treatment': 19199,
#  'deadly': 5426,
#  'happened': 8753,
#  'hagerstown': 8682,
#  'today': 18976,
#  'll': 11562,
#  'details': 5675,
#  'your4state': 21295,
#  'whag': 20529,
#  'flowri': 7566,
#  'were': 20491,
#  'marinading': 12031,
#  'only': 13844,
#  'even': 6919,
#  'fucking': 7860,
#  'mfs': 12348,
#  'drive': 6166,
#  'norwaymfa': 13399,
#  'bahrain': 2634,
#  'previously': 14945,
#  'road': 16177,
#  'killed': 10830,
#  'explosion': 7043,
#  'gfjfgtodad': 8152,
#  'still': 17899,
#  'heard': 8893,
#  'leaders': 11255,
#  'kenya': 10747,
#  'forward': 7687,
#  'comment': 4642,
#  'issue': 10068,
#  'disciplinary': 5844,
#  'measures': 12203,
#  'arrestpastornganga': 2244,
#  'aftershock_delo': 1676,
#  'scuf': 16752,
#  'ps': 15090,
#  'game': 8003,
#  'cya': 5205,
#  'himself': 9061,
#  'further': 7900,
#  'once': 13827,
#  'effort': 6479,
#  'gets': 8138,
#  'painful': 14152,
#  'win': 20626,
#  'roger': 16227,
#  'bannister': 2683,
#  '320': 544,
#  'ir': 10012,
#  'icemoon': 9496,
#  'aftershock': 1675,
#  'ynxnvvkcda': 21265,
#  'djicemoon': 5938,
#  'dubstep': 6239,
#  'trapmusic': 19178,
#  'dnb': 5982,
#  'dance': 5305,
#  'ices': 9498,
#  'weqpesenku': 20490,
#  'victory': 20049,
#  'bargain': 2707,
#  'basement': 2730,
#  'prices': 14949,
#  'dwight': 6303,
#  'david': 5372,
#  'eisenhower': 6514,
#  'vam5podgyw': 19917,
#  'zevakjapcz': 21446,
#  'nobody': 13344,
#  'remembers': 15845,
#  'came': 3816,
#  'charles': 4168,
#  'schulz': 16703,
#  'im': 9646,
#  'speaking': 17611,
#  'someone': 17505,
#  'using': 19807,
#  'xb1': 20979,
#  'most': 12728,
#  'also': 1898,
#  'harder': 8774,
#  'conflict': 4739,
#  'glorious': 8270,
#  'triumph': 19254,
#  'thomas': 18789,
#  'paine': 14151,
#  'growingupspoiled': 8506,
#  'clay': 4410,
#  'pigeon': 14539,
#  'shooting': 17071,
#  'because': 2850,
#  'guess': 8551,
#  'one': 13828,
#  'actually': 1562,
#  'wants': 20314,
#  'any': 2079,
#  'free': 7765,
#  'tc': 18470,
#  'terrifying': 18594,
#  'best': 2963,
#  'roller': 16243,
#  'coaster': 4529,
#  'ever': 6925,
#  'disclaimer': 5845,
#  'very': 20002,
#  'few': 7350,
#  'xmwodfmtui': 21032,
#  'm4jdzmgjow': 11843,
#  'n0uhasfkbv': 12967,
#  'e14epzhoth': 6334,
#  '22a9d5do6q': 390,
#  'kjfordays': 10882,
#  'seeing': 16811,
#  'issues': 10070,
#  'thyzomvwu0': 18857,
#  '83joo0xk29': 1136,
#  'wisdomwed': 20665,
#  'bonus': 3312,
#  'minute': 12479,
#  'daily': 5269,
#  'habits': 8674,
#  'could': 4899,
#  'really': 15672,
#  'improve': 9704,
#  'many': 12001,
#  'already': 1894,
#  'lifehacks': 11424,
#  'tbm9fqb8cw': 18462,
#  'protect': 15060,
#  'yourself': 21298,
#  'profit': 15006,
#  'global': 8262,
#  'financial': 7415,
#  'meltdown': 12257,
#  'wiedemer': 20597,
#  'wztz4hgmvq': 20940,
#  'moment': 12644,
#  'scary': 16684,
#  'guy': 8598,
#  'behind': 2895,
#  'screaming': 16736,
#  'bloody': 3214,
#  'murder': 12868,
#  'silverwood': 17166,
#  '2010': 356,
#  'full': 7876,
#  'streaming': 17968,
#  'youtube': 21303,
#  'vve3usesgf': 20221,
#  'book': 3314,
#  'f6ntuc734z': 7114,
#  'esquireattire': 6843,
#  'sometimes': 17509,
#  'face': 7130,
#  'difficulties': 5786,
#  'doing': 6015,
#  'wrong': 20867,
#  'joel': 10401,
#  'osteen': 13977,
#  'thing': 18765,
#  'stands': 17798,
#  'between': 2981,
#  'dream': 6139,
#  'belief': 2908,
#  'possible': 14793,
#  'brown': 3538,
#  'praise': 14864,
#  'ministry': 12468,
#  'tells': 18549,
#  'wdyouth': 20421,
#  'biblestudy': 3017,
#  'ujk0e5gbcc': 19554,
#  'remembering': 15843,
#  'die': 5771,
#  'avoid': 2489,
#  'trap': 19176,
#  'thinking': 18769,
#  'lose': 11676,
#  'jobs': 10394,
#  'tried': 19242,
#  'orange': 13922,
#  'never': 13178,
#  'same': 16560,
#  'onfireanders': 13835,
#  'bb': 2774,
#  'jv8ppkhjy7': 10564,
#  'kick': 10804,
#  'off': 13689,
#  'want': 20310,
#  'making': 11948,
#  'say': 16650,
#  'cannot': 3864,
#  'done': 6039,
#  'should': 17085,
#  'interrupt': 9933,
#  'those': 18797,
#  'george': 8119,
#  'bernard': 2956,
#  'shaw': 17003,
#  'oyster': 14084,
#  'shell': 17019,
#  'andrew': 1990,
#  'carnegie': 3943,
#  'anyone': 2083,
#  'need': 13133,
#  'play': 14641,
#  'hybrid': 9410,
#  'slayer': 17318,
#  'ps4': 15094,
#  'eu': 6884,
#  'hmu': 9115,
#  'cod8sandscrims': 4547,
#  'empirikgaming': 6641,
#  'codawscrims': 4548,
#  '4tp_kotc': 775,
#  '4tpfa': 776,
#  'aftershock_org': 1677,
#  'experts': 7026,
#  'france': 7744,
#  'begin': 2882,
#  'examining': 6959,
#  'airplane': 1749,
#  'debris': 5451,
#  'found': 7695,
#  'reunion': 16003,
#  'island': 10059,
#  'french': 7791,
#  'air': 1740,
#  'yvvpznzmxg': 21355,
#  'strict': 17987,
#  'liability': 11396,
#  'context': 4795,
#  'pilot': 14554,
#  'error': 6818,
#  'common': 4659,
#  'component': 4694,
#  'aviation': 2486,
#  'cr': 4959,
#  '6cz3bohrd4': 952,
#  'crobscarla': 5047,
#  'lifetime': 11430,
#  'odds': 13665,
#  'dying': 6317,
#  '8015': 1121,
#  'wedn': 20452,
#  'bkpfpogysi': 3128,
#  'alexalltimelow': 1823,
#  'awwww': 2523,
#  'cuties': 5174,
#  'good': 8333,
#  'job': 10390,
#  'family': 7186,
#  'members': 12261,
#  'osama': 13966,
#  'bin': 3070,
#  'laden': 11104,
#  'ironic': 10031,
#  'mhmmm': 12364,
#  'gov': 8372,
#  'suspect': 18209,
#  'goes': 8314,
#  'engine': 6698,
#  'tyjxrfd3st': 19440,
#  'via': 20027,
#  'wings': 20646,
#  '29': 430,
#  '07': 25,
#  'i7kztevb2v': 9451,
#  'cessna': 4096,
#  'ocampo': 13641,
#  'coahuila': 4523,
#  'mexico': 12336,
#  'july': 10530,
#  'four': 7699,
#  'men': 12271,
#  'including': 9740,
#  'state': 17830,
#  'government': 8375,
#  'official': 13703,
#  'watchthevideo': 20368,
#  'p64xrvgjik': 14109,
#  'lsmx2vwr3j': 11732,
#  'wednesday': 20455,
#  'began': 2879,
#  'kca': 10699,
#  'votejkt48id': 20183,
#  'mbataweel': 12155,
#  'rip': 16118,
#  'binladen': 3074,
#  'almost': 1882,
#  'coworker': 4941,
#  'nudes': 13492,
#  'mode': 12607,
#  'mickinyman': 12383,
#  'theatlantic': 18675,
#  'might': 12407,
#  'wreck': 20846,
#  'politics': 14745,
#  'tagzbcxfj0': 18360,
#  'mlb': 12568,
#  'unbelievably': 19597,
#  'insane': 9858,
#  'airport': 1751,
#  'aircraft': 1743,
#  'aeroplane': 1632,
#  'runway': 16412,
#  'freaky': 7760,
#  'cezhq7czll': 4098,
#  'airplaneåê': 1750,
#  'wq3wjsgphl': 20831,
#  'tfcdronra6': 18628,
#  'usama': 19784,
#  'ladins': 11106,
#  'naturally': 13067,
#  'plane': 14620,
#  'festival': 7345,
#  'kq9ae6ap2b': 10982,
#  'death': 5441,
#  'carfest': 3926,
#  'gibyqhhkpk': 8190,
#  'dtn': 6228,
#  'brazil': 3429,
#  'exp': 7005,
#  'm9ig3wq8lq': 11863,
#  'v4smaeslk5': 19876,
#  'ûïairplane': 21604,
#  'wtf': 20884,
#  'ûªt': 21599,
#  'believe': 2910,
#  'eyes': 7086,
#  '6ffylajwps': 959,
#  'nicole': 13248,
#  'fletcher': 7530,
#  'victim': 20041,
#  'crashed': 4979,
#  'times': 18892,
#  'ago': 1705,
#  'little': 11518,
#  'bit': 3094,
#  'trauma': 19182,
#  'although': 1905,
#  'she': 17008,
#  'omg': 13817,
#  'xdxdprcpns': 20994,
#  'bro': 3509,
#  ...}

# %%
x.shape
# Out:
# (7613, 21637)

# %%
y.shape
# Out:
# (7613,)

# %%
#task is to reduce the x shape and it has a huge sparse matrix

# %%
type(x)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
type(y)
# Out:
# pandas.core.series.Series
